# %% [markdown]
# # A Machine Learning Approach Towards Customer Lead Classification

# %% [markdown]
# ## 1. Import Modules

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler
from numpy import set_printoptions
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ## 2. The Data

# %% [markdown]
# ### 2.1 Read CSV file

# %%
data = pd.read_csv('Desktop/vierde-jaar/1-industrial-project/0-data/leads-data-full.csv', sep=';', low_memory=False)

# %% [markdown]
# ### 2.2 Display top of data frame

# %%
data.head()
# Out:
#                                      Id     Topic  ec_leadsource  \
# 0  22C2123A-A7A1-EA11-A811-000D3A49DE7B  New lead    100000003.0
# 1  24C2123A-A7A1-EA11-A811-000D3A49DE7B  New lead    100000003.0
# 2  26C2123A-A7A1-EA11-A811-000D3A49DE7B  New lead    100000003.0
# 3  28C2123A-A7A1-EA11-A811-000D3A49DE7B  New lead    100000003.0
# 4  2AC2123A-A7A1-EA11-A811-000D3A49DE7B  New lead    100000003.0
#
#   ec_leadsource_label  ec_assessmentifnecessary  \
# 0           Campaigns                       NaN
# 1           Campaigns                       NaN
# 2           Campaigns                       NaN
# 3           Campaigns                       NaN
# 4           Campaigns               100000000.0
#
#   ec_assessmentifnecessary_label  CSC Source CSC Source Label  CSC Notes  \
# 0                            NaN         NaN              NaN        NaN
# 1                            NaN         NaN              NaN        NaN
# 2                            NaN         NaN              NaN        NaN
# 3                            NaN         NaN              NaN        NaN
# 4                      Completed         NaN              NaN        NaN
#
#   CSC Notes Label  ...  ownerid_entitytype         createdon  \
# 0             NaN  ...          systemuser  2020/05/29 14:24
# 1             NaN  ...          systemuser  2020/05/29 14:24
# 2             NaN  ...          systemuser  2020/05/29 14:24
# 3             NaN  ...          systemuser  2020/05/29 14:24
# 4             NaN  ...          systemuser  2020/05/29 14:24
#
#          modifiedon       Import Date  Follow Up Date 1 Follow Up Date 2  \
# 0  2021/06/28 11:26  2020/05/29 14:24               NaN              NaN
# 1  2021/06/28 11:26  2020/05/29 14:24               NaN              NaN
# 2  2021/06/28 11:28  2020/05/29 14:24               NaN              NaN
# 3  2021/06/28 11:26  2020/05/29 14:24               NaN              NaN
# 4  2020/10/05 21:16  2020/05/29 14:24               NaN              NaN
#
#    Follow Up Date 3 Follow Up Date 4 Merged  Merged_label
# 0               NaN              NaN  False            No
# 1               NaN              NaN  False            No
# 2               NaN              NaN  False            No
# 3               NaN              NaN  False            No
# 4               NaN              NaN  False            No
#
# [5 rows x 97 columns]

# %% [markdown]
# ## 3. Data Exploration

# %% [markdown]
# ### 3.1 Data dimensions and types

# %%
data.shape
# Out:
# (87456, 97)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87456 entries, 0 to 87455
# Data columns (total 97 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Id                                          87456 non-null  object
#  1   Topic                                       87207 non-null  object
#  2   ec_leadsource                               84033 non-null  float64
#  3   ec_leadsource_label                         84033 non-null  object
#  4   ec_assessmentifnecessary                    8525 non-null   float64
#  5   ec_assessmentifnecessary_label              8525 non-null   object
#  6   CSC Source                                  23644 non-null  float64
#  7   CSC Source Label                            23644 non-null  object
#  8   CSC Notes                                   27278 non-null  float64
#  9   CSC Notes Label                             27278 non-null  object
#  10  ec_abovethelineadvertising                  1861 non-null   float64
#  11  ec_abovethelineadvertising_label            1861 non-null   object
#  12  ec_belowthelineadvertising                  24460 non-null  float64
#  13  ec_belowthelineadvertising_label            24460 non-null  object
#  14  ec_onlinesocialmedia                        14975 non-null  float64
#  15  ec_onlinesocialmedia_label                  14975 non-null  object
#  16  ec_campaigns                                22645 non-null  float64
#  17  ec_campaigns_label                          22645 non-null  object
#  18  Campaign Name                               26660 non-null  object
#  19  ec_whatareyoulookingfor                     45294 non-null  float64
#  20  ec_whatareyoulookingfor_label               45294 non-null  object
#  21  ec_intendedstartdate                        57330 non-null  object
#  22  ec_sendgeneralmarketingmaterial             87456 non-null  bool
#  23  ec_sendgeneralmarketingmaterial_label       87456 non-null  object
#  24  ec_datesent                                 38661 non-null  object
#  25  ec_relationshiptolearner                    23989 non-null  float64
#  26  ec_relationshiptolearner_label              23989 non-null  object
#  27  ec_learnersgender                           12890 non-null  float64
#  28  ec_learnersgender_label                     12890 non-null  object
#  29  Learner Age                                 11792 non-null  float64
#  30  ec_gradeofenrolment                         65583 non-null  float64
#  31  ec_gradeofenrolment_label                   65583 non-null  object
#  32  Additional Grades                           11969 non-null  object
#  33  ec_schoolvisited                            12494 non-null  float64
#  34  ec_schoolvisited_label                      12494 non-null  object
#  35  Individual Visiting Date                    487 non-null    object
#  36  Street                                      2131 non-null   object
#  37  Suburbs                                     15321 non-null  object
#  38  Postal Code                                 3282 non-null   object
#  39  City/Town                                   10456 non-null  object
#  40  Country                                     73396 non-null  object
#  41  Province                                    75498 non-null  object
#  42  Campus                                      78855 non-null  object
#  43  School                                      78842 non-null  object
#  44  LeadRating                                  39702 non-null  float64
#  45  Lead Rating label                           39702 non-null  object
#  46  Aftercare Needed                            23670 non-null  float64
#  47  Aftercare Needed label                      23670 non-null  object
#  48  Boarding School Needed                      24105 non-null  float64
#  49  Boarding School Needed label                24105 non-null  object
#  50  Bursary / Scholarship Applicable            2838 non-null   float64
#  51  Bursary / Scholarship Applicable label      2838 non-null   object
#  52  Transportation Method                       1967 non-null   float64
#  53  Transportation Method label                 1967 non-null   object
#  54  Additional Siblings                         144 non-null    object
#  55  Reason For Wanting To Leave Current School  15144 non-null  object
#  56  What is important you as a parent           23397 non-null  float64
#  57  What is important you as a parent label     23397 non-null  object
#  58  Learners Hobbies And Interests              454 non-null    float64
#  59  Learners Hobbies And Interests label        454 non-null    object
#  60  Current School Learner Is Attending         437 non-null    object
#  61  Enrolment Discount Applicable               48115 non-null  float64
#  62  Enrolment Discount Applicable label         48115 non-null  object
#  63  Discount End Date                           14942 non-null  object
#  64  Corporate Discount Applicable               6421 non-null   float64
#  65  Corporate Discount Applicable label         6421 non-null   object
#  66  School Fee Discount Applicable              22907 non-null  float64
#  67  School Fee Discount Applicable label        22907 non-null  object
#  68  Special Offer Discount                      52 non-null     object
#  69  Additional Profile Information              93 non-null     object
#  70  School Fees Account Holder                  60 non-null     object
#  71  Parents Marital Status                      128 non-null    float64
#  72  Parents Marital Status label                128 non-null    object
#  73  Parents Employer                            45 non-null     object
#  74  Parents Income Range                        2 non-null      object
#  75  Family Code                                 3802 non-null   object
#  76  Academic check                              87456 non-null  bool
#  77  Academic check label                        87456 non-null  object
#  78  Credit check                                87456 non-null  bool
#  79  Credit check label                          87456 non-null  object
#  80  Assessment if necessary                     8525 non-null   float64
#  81  Assessment if necessary label               8525 non-null   object
#  82  statecode                                   87456 non-null  int64
#  83  statecode_label                             87456 non-null  object
#  84  statuscode                                  87456 non-null  int64
#  85  statuscode_label                            87456 non-null  object
#  86  ownerid                                     87456 non-null  object
#  87  ownerid_entitytype                          87456 non-null  object
#  88  createdon                                   87456 non-null  object
#  89  modifiedon                                  87456 non-null  object
#  90  Import Date                                 87456 non-null  object
#  91  Follow Up Date 1                            15560 non-null  object
#  92  Follow Up Date 2                            17153 non-null  object
#  93  Follow Up Date 3                            15571 non-null  object
#  94  Follow Up Date 4                            13880 non-null  object
#  95  Merged                                      87456 non-null  bool
#  96  Merged_label                                87456 non-null  object
# dtypes: bool(4), float64(26), int64(2), object(65)
# memory usage: 62.4+ MB

# %% [markdown]
# ### 3.2 Send target feature to back

# %%
target = ['LeadRating', 'Lead Rating label']
data = training_df[[c for c in training_df if c not in target] 
        + [c for c in target if c in training_df]]
target_df.to_csv('training-target.csv', index=False)
